# %% [markdown]
# <a href="https://colab.research.google.com/github/siva-training/GPT2-python-code-generator/blob/main/pushtohub.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install transformers
# Out:
# ...
#      |████████████████████████████████| 2.8 MB 5.2 MB/s
# ...
#      |████████████████████████████████| 895 kB 37.9 MB/s
# ...
#      |████████████████████████████████| 636 kB 37.6 MB/s
# ...
#      |████████████████████████████████| 52 kB 1.3 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 47.9 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
# !pip install deepspeed
# Out:
# ...
#      |████████████████████████████████| 477 kB 5.3 MB/s
# ...
#      |████████████████████████████████| 216 kB 49.7 MB/s
# ...
#      |████████████████████████████████| 108 kB 48.9 MB/s
# ...
#      |████████████████████████████████| 15.2 MB 38 kB/s
# ...
#   Created wheel for deepspeed: filename=deepspeed-0.5.3-py3-none-any.whl size=480190 sha256=3f7fd4b758cb90f7bf9918150f8dcb5e009cdf243b4ddee43827d7894bb5ebc7
#   Stored in directory: /root/.cache/pip/wheels/8f/a3/c9/2d8777fa5b18c86e8d1dd2d8197c13596ae14ac5996fb329be
# Successfully built deepspeed
# ...

# %%
# !pip install datasets
# Out:
# ...
#      |████████████████████████████████| 270 kB 5.4 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 42.2 MB/s
# ...
#      |████████████████████████████████| 243 kB 46.8 MB/s
# ...
#      |████████████████████████████████| 119 kB 41.8 MB/s
# ...
#      |████████████████████████████████| 142 kB 50.6 MB/s
# ...
#      |████████████████████████████████| 294 kB 49.7 MB/s
# ...

# %%
# %%bash
# git clone https://github.com/siva-training/GPT2-python-code-generator.git
# cd GPT2-python-code-generator
# git clone https://github.com/huggingface/transformers.git
# cd transformers
# git checkout b39bd763e8
# Out:
# Cloning into 'GPT2-python-code-generator'...
# Cloning into 'transformers'...
# Note: checking out 'b39bd763e8'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by performing another checkout.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -b with the checkout command again. Example:
#
#   git checkout -b <new-branch-name>
#
# HEAD is now at b39bd763e Update README.md

# %%
# %%bash
# cd GPT2-python-code-generator
# git checkout dev
# python create_dataset.py
# Out:
# Branch 'dev' set up to track remote branch 'dev' from 'origin'.
# files:  460
# Switched to a new branch 'dev'
# Cloning into 'resources/TerraformRepo.git'...

# %%
import torch
from transformers import GPT2LMHeadModel, GPT2Tokenizer
tokenizer = GPT2Tokenizer.from_pretrained('distilgpt2')
model = GPT2LMHeadModel.from_pretrained('distilgpt2')
special_tokens_dict = {'bos_token': '<BOS>', 'eos_token': '<EOS>', 'pad_token': '<PAD>'}
num_added_toks = tokenizer.add_special_tokens(special_tokens_dict)
# Out:
# Downloading:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/762 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/353M [00:00<?, ?B/s]

# %%
# %%bash
# cd GPT2-python-code-generator
# deepspeed transformers/examples/language-modeling/run_clm.py --do_train --do_eval  --logging_first_step --evaluation_strategy epoch --logging_steps 2000 --model_name_or_path distilgpt2 --model_type distilgpt2 --num_train_epochs 5 --output_dir finetune --per_device_eval_batch_size 5 --per_device_train_batch_size 5 --save_steps 2000 --save_total_limit 20 --train_file data/train.csv --validation_file data/test.csv --overwrite_output_dir
# Out:
# [2021-09-19 06:53:44,048] [WARNING] [runner.py:122:fetch_hostfile] Unable to find hostfile, will proceed with training with local resources only.
# [2021-09-19 06:53:44,069] [INFO] [runner.py:360:main] cmd = /usr/bin/python3 -u -m deepspeed.launcher.launch --world_info=eyJsb2NhbGhvc3QiOiBbMF19 --master_addr=127.0.0.1 --master_port=29500 transformers/examples/language-modeling/run_clm.py --do_train --do_eval --logging_first_step --evaluation_strategy epoch --logging_steps 2000 --model_name_or_path distilgpt2 --model_type distilgpt2 --num_train_epochs 5 --output_dir finetune --per_device_eval_batch_size 5 --per_device_train_batch_size 5 --save_steps 2000 --save_total_limit 20 --train_file data/train.csv --validation_file data/test.csv --overwrite_output_dir
# [2021-09-19 06:53:44,819] [INFO] [launch.py:73:main] 0 NCCL_VERSION 2.7.8
# [2021-09-19 06:53:44,819] [INFO] [launch.py:80:main] WORLD INFO DICT: {'localhost': [0]}
# ...

# %%
# !git config --global credential.helper store

# %%
# !huggingface-cli login
# Out:
#         _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#         _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#         _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#         _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#         _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#
# Username: sivavee.train@gmail.com
# Password:
# Login successful
# Your token has been saved to /root/.huggingface/token
# Authenticated through git-crendential store but this isn't the helper defined on your machine.
# You will have to re-authenticate when pushing to the Hugging Face Hub. Run the following command in your terminal to set it as the default
#
# ...
